# %% [markdown]
# ## OTEANN with Transformers
#
# This notebook investigates the orthographic depth of some spelling systems.
#
# This is a new version of OTEANN, which is now implemented with a GPT model instead of a Seq2Seq.
#
# The code used in this pages mainly comes from https://github.com/karpathy/minGPT (under MIT licence)

# %%
# set up logging
import logging
logging.basicConfig(
        format="%(asctime)s - %(levelname)s - %(name)s -   %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S",
        level=logging.ERROR,
)

# %%
import os
import sys
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.nn import functional as F
from mingpt.model import GPT, GPTConfig
from mingpt.trainer import Trainer, TrainerConfig
from mingpt.utils import sample

# %%
# make deterministic
#from mingpt.utils import set_seed
#set_seed(42)

# %%
# These first configuration parameters are hyperparameters that we will need to tune
CONFIG = {            
    'episodes': 1,
    'n_train': 10000,
    'n_layer': 4,
    'n_head': 4,
    'n_embd': 336,
    'batch_size': 256
}

ROOT_DIR = os.getcwd()

# These other configuration parameters will not be tuned
def extend_config(config): 
    #config['languages'] = ['ent', 'eno','ar', 'br', 'de', 'en', 'es', 'fi', 'fr', 'fro', 'it', 'ko', 'nl', 'pt', 'ru', 'sh', 'tr']
    config['languages'] = ['en', 'fr'] 
    config['n_test'] = 100
    config['print_predictions'] = True
    config['do_finetune'] = False
    config['n_samples'] = config['n_train'] + config['n_test']
    config['label'] = 'oteann' + '_' + str(config['n_samples'])
    config['root_dir'] = ROOT_DIR    
    config['output_max_len'] = 25
    config['block_size'] = 63
    config['do_train'] = True  # allows skipping training between multiple re-runs
    config['tasks'] = ['write', 'read']
    config['subdatasets_dir'] = 'subdatasets'
    config['sep'] = ','
    config['features'] =  ['Language', 'Task', 'Input', 'Output']    
    config['trial_dir'] = os.getcwd()
    config['trial_filename'] = config['trial_dir'] + '/' + config['label']
    config['subdataset'] = 'wikt_samples.csv' # postfix from fonetik.fr's files 
    config['train_filename'] = config['trial_filename'] + '_train.csv'
    config['test_filename'] = config['trial_filename'] + '_test.csv'
    config['model_filename'] = config['trial_filename'] + '_model.pt'
    config['results_filename'] = config['trial_filename'] + '_results.csv'
    config['aggregated_subdatasets'] = config['root_dir'] + '/' + config['subdataset']
    full_text = open(config['aggregated_subdatasets'], 'r').read() 
    config['chars'] = sorted(list(set(full_text)))
    
    if not os.path.exists(config['trial_dir']):
    	os.mkdir(config['trial_dir'])
    
    return config

# %%
def add_samples(config, language, task):
    
    filename = config['root_dir'] + '/' + config['subdatasets_dir'] + '/' + language + '_' + config['subdataset']
    if config['episodes'] == 1:
        print('%s: processing "%s" data from %s' %(language, task, filename))
    
    #!wget -q -N https://fonétik.fr/$filename
    
    wanted_samples = config['n_samples']
    
    df = pd.read_csv(filename)    
    if df.shape[0] < wanted_samples:
        print('WARNING: ', language, 'n_samples=', df.shape[0])
        if df.shape[0] > config['n_test']:
            wanted_samples = df.shape[0]
        else:
            print('ERROR: ', language, 'not enough samples')
            return

    df = df.sample(wanted_samples)
    
    df_train = pd.DataFrame(columns=config['features'])
    df_test = pd.DataFrame(columns=config['features'])
        
    # only keep 2 columns
    df = df[['Word', 'Pronunciation']]
    
    n_max = df.shape[0]
    n_test = config['n_test']
    n_train = int(n_max - n_test)
    
    n = 0
    for index, line in df.iterrows():
        
        word = line['Word']
        try:
            l_word = len(word)
            if l_word > config['output_max_len']:
                continue
        except:
            continue            
        pron = line['Pronunciation']
        try:
            l_pron = len(pron)
            if l_pron > config['output_max_len']:
                continue
        except:
            continue
        l_word = len(word)
        l_pron = len(pron)
        
        if task == 'read':
            input = word        
            output = pron 
        elif task == 'write':
            input = pron       
            output = word 
        else:
            print('ERROR: task=',task,'should not happen')
            return
        
        sample = {'Language': language, 'Task':task, 'Input': input, 'Output': output}
        if n < n_test:
            df_test = df_test.append(sample, ignore_index = True)
        else:
            df_train = df_train.append(sample, ignore_index = True)
        n += 1
            
    # append results to our train and test datasets
    df_train.to_csv(config['train_filename'], mode='a', index=False, header=False)
    df_test.to_csv(config['test_filename'], mode='a', index=False, header=False)
    
    return
    
def generate_datasets(config):
    
    # init our two datasets
    df_train = pd.DataFrame(columns=config['features'])
    df_test = pd.DataFrame(columns=config['features'])
    
    # overwrite previous files
    df_train.to_csv(config['train_filename'], index=False, header=False)
    df_test.to_csv(config['test_filename'], index=False, header=False)
    
    # fill our two datasets
    for language in config['languages']:
        for task in config['tasks']:
            add_samples(config, language, task)


def shuffle_datasets(config):
    df_train = pd.read_csv(config['train_filename'], header=None, names=config['features'])    
    df_train = df_train.sample(frac=1)
    df_train.to_csv(config['train_filename'], index=False, header=False)
    
    df_test = pd.read_csv(config['test_filename'], header=None, names=config['features'])
    df_test = df_test.sample(frac=1)
    df_test.to_csv(config['test_filename'], index=False, header=False)
    
# minimalist check of the datasets generated
def check_datasets(config, debug=False):
    df_train = pd.read_csv(config['train_filename'], header=None, names=config['features'])
    df_test = pd.read_csv(config['test_filename'], header=None, names=config['features'])
    
    for step in ['train', 'test']:
        if step == 'train':
            df = df_train
        else:
            df = df_test
            
        if debug:
            print(step, 'shape:', df.shape)
            print(step, 'Input min len:', df.Input.str.len().min())
            print(step, 'Input max len:', df.Input.str.len().max())
            print(step, 'Output min len:', df.Output.str.len().min())
            print(step, 'Output max len:', df.Output.str.len().max())
        
        assert(df.Input.str.len().max() <= config['output_max_len'])
        assert(df.Output.str.len().max() <= config['output_max_len'])

# %%
def init_train_test_datasets(config):
    generate_datasets(config)
    shuffle_datasets(config)
    check_datasets(config)

# %%
import math
from torch.utils.data import Dataset

class CharDataset(Dataset):

    def __init__(self, chars, data, block_size, debug=False):
        #chars = sorted(list(set(data)))
        data_size, vocab_size = len(data), len(chars)
        if debug:
            print('data has %d characters, %d unique.' % (data_size, vocab_size))
        
        self.stoi = { ch:i for i,ch in enumerate(chars) }
        self.itos = { i:ch for i,ch in enumerate(chars) }
        self.block_size = block_size
        self.vocab_size = vocab_size
        self.data = data
    
    def __len__(self):
        return len(self.data) - self.block_size

    def __getitem__(self, idx):
        # grab a chunk of (block_size + 1) characters from the data
        chunk = self.data[idx:idx + self.block_size + 1]
        # encode every character to an integer
        dix = [self.stoi[s] for s in chunk]
        """
        arrange data and targets so that the first i elements of x
        will be asked to predict the i-th element of y. Notice that
        the eventual language model will actually make block_size
        individual predictions at the same time based on this data,
        so we are being clever and amortizing the cost of the forward
        pass of the network. So for example if block_size is 4, then
        we could e.g. sample a chunk of text "hello", the integers in
        x will correspond to "hell" and in y will be "ello". This will
        then actually "multitask" 4 separate examples at the same time
        in the language model:
        - given just "h", please predict "e" as next
        - given "he" please predict "l" next
        - given "hel" predict "l" next
        - given "hell" predict "o" next
        
        In addition, because the DataLoader will create batches of examples,
        every forward/backward pass during traning will simultaneously train
        a LOT of predictions, amortizing a lot of computation. In particular,
        for a batched input of integers X (B, T) where B is batch size and
        T is block_size and Y (B, T), the network will during training be
        simultaneously training to make B*T predictions, all at once! Of course,
        at test time we can paralellize across batch B, but unlike during training
        we cannot parallelize across the time dimension T - we have to run
        a forward pass of the network to recover the next single character of the 
        sequence along each batch dimension, and repeatedly always feed in a next
        character to get the next one.
        
        So yes there is a big asymmetry between train/test time of autoregressive
        models. During training we can go B*T at a time with every forward pass,
        but during test time we can only go B at a time, T times, with T forward 
        passes.
        """
        x = torch.tensor(dix[:-1], dtype=torch.long)
        y = torch.tensor(dix[1:], dtype=torch.long)
        return x, y

# %%
def predict_pron(config, train_dataset, trainer, model, word):
    try:
        x = torch.tensor([train_dataset.stoi[s] for s in word], dtype=torch.long)[None,...].to(trainer.device)
        y = sample(model, x, config['output_max_len'], temperature=1.0, sample=True, top_k=10)[0]
        completion = ''.join([train_dataset.itos[int(i)] for i in y])
    except:
        e = sys.exc_info()[0]
        print('predict_pron(): error %s for word:%s' % (e, word))
        # Typically, this can happen if a tested word contains a char
        # that did not existing during the training step
        completion = 'N/A'
    return completion

# %%
def train(config):

    training_t0 = datetime.datetime.now()  
    
    block_size = config['block_size']
    
    print("config['train_filename']:", config['train_filename'])        
    text = open(config['train_filename'], 'r').read() 
    train_dataset = CharDataset(config['chars'], text, block_size, debug=True) 

    # create model
    mconf = GPTConfig(train_dataset.vocab_size, train_dataset.block_size,
                      n_layer=config['n_layer'], 
                      n_head=config['n_head'], 
                      n_embd=config['n_embd'])

    model = GPT(mconf)

    pytorch_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print('ANN parameters: %d' % pytorch_total_params)
    
    # train
    tconf = TrainerConfig(max_epochs=2, batch_size=config['batch_size'], learning_rate=6e-4,
                          lr_decay=True, warmup_tokens=512*20, 
                          final_tokens=2*len(train_dataset)*block_size,
                          num_workers=4,
                          tqdm=not config['do_finetune'])
    trainer = Trainer(model, train_dataset, None, tconf)
    trainer.train()
    training_t1 = datetime.datetime.now()  
    training_duration = training_t1 - training_t0
    print('training_duration', training_duration)
    
    torch.save(model.state_dict(), config['model_filename'])
    
    return model

# %%
def get_model(config):
    # following two lines are copied from train()
    block_size = config['block_size']
    text = open(config['train_filename'], 'r').read() 
    train_dataset = CharDataset(config['chars'], text, config['block_size']) 
                       
    mconf = GPTConfig(train_dataset.vocab_size, train_dataset.block_size,                       
                      n_layer=config['n_layer'], 
                      n_head=config['n_head'], 
                      n_embd=config['n_embd'])
    model = GPT(mconf)
    model.load_state_dict(torch.load(config['model_filename']))
    model.eval()
    return model

# %%
def test(config, task, language, df_results):
    
    model = get_model(config)
    
    # followwing two lines are copied from train()
    block_size = config['block_size']
    text = open(config['train_filename'], 'r').read() 
    train_dataset = CharDataset(config['chars'], text, block_size) 

    
    tconf = TrainerConfig(max_epochs=2, batch_size=config['batch_size'], learning_rate=6e-4,
                          lr_decay=True, warmup_tokens=512*20, 
                          final_tokens=2*len(train_dataset)*block_size,
                          num_workers=4)
    trainer = Trainer(model, train_dataset, None, tconf)
    
    # test
    testing_t0 = datetime.datetime.now() 
    
    df_test = pd.read_csv(config['test_filename'], header=None, names=config['features'])    

    n = 0
    n_ok = 0
    n_ko = 0
    for index, row in df_test.iterrows():
        
        if row.Task != task or row.Language != language:
            continue
        
        n += 1
        
        # build the context 
        context = language + ',' + task + ',' + row.Input + ','
        
        # get the predicted output string
        prediction_padded = predict_pron(config, train_dataset, trainer, model, context)
        
        # identify where the interesting output is in the raw output
        if prediction_padded.startswith(context):
            
            # remove unwanted prefix
            prediction_padded = prediction_padded[len(context):]     
            
            # remove unwanted postfix (i.e. remove padding)
            eos = prediction_padded.find('\n', 1)
            if eos < 0:
                n_ko += 1
            else:
                #prediction = prediction_padded[:eos_p]
                #target = row.Output[:eos_t]
                prediction = prediction_padded[:eos]
                target = row.Output
                # check if prediction is same as target
                if prediction == target:
                    n_ok += 1
                    if config['print_predictions'] and language != 'eno':
                        print('input: %s,%s,%s => prediction:%s ok (target:%s)' 
                              % (language, task, row.Input, prediction, target))                    
                else:
                    n_ko += 1
                    if config['print_predictions'] and language != 'eno':
                        print('input: %s,%s,%s => prediction:%s KO! (target:%s)' 
                              % (language, task, row.Input, prediction, target))                    
        else:
            n_ko += 1

    pctg_ok = int(n_ok/n*100)
    pctg_ko = 100 - pctg_ok
    if config['episodes'] == 1:
        print('%s %5s: n=%d, n_ok=%d, n_ko=%d => %%n_ok=%d%%' % (language, task, n, n_ok, n_ko, pctg_ok))
    testing_t1 = datetime.datetime.now()  
    test_duration = testing_t1 - testing_t0
    
    dict_res = {'lang': language, 'task':task, 'test_accuracy': n_ok/n, 
                #'training_duration': training_duration, 
                'test_duration': test_duration}
    return dict_res

# %%
def train_and_tests(config):
    
    # open the file for being able to append the results of this test
    # otherwise create a new one
    df_results = pd.DataFrame()

    for episode in range(config['episodes']):
        print('episode:', episode)
             
        init_train_test_datasets(config)
        
        # train the ANN for all available languages in the training dataset
        # i.e. multi-language training
        train(config)
        
        # test the ANN for each languages
        for language in config['languages']:
            for task in config['tasks']:
                dict_res = test(config, task, language, df_results)
                # put the results as a new line in the CSV history file
                df_res = pd.DataFrame(data = [dict_res.values()], columns = dict_res.keys())
                df_results = pd.concat([df_results, df_res], axis=0, ignore_index=True, sort=False)
                df_results.to_csv(config['results_filename'], index=None, header=True)
                
    acc = df_results.test_accuracy.mean()
    print('accuracy:%.2f' % acc)
    
    return df_results

# %%
def tests(config):

    # open the file for being able to append the results of this test
    # otherwise create a new one
    df_results = pd.DataFrame()

    for episode in range(config['episodes']):
        print('episode:', episode)
        
        # test the ANN for each languages
        for language in config['languages']:
            for task in config['tasks']:
                dict_res = test(config, task, language, df_results)
                # put the results as a new line in the CSV history file
                df_res = pd.DataFrame(data = [dict_res.values()], columns = dict_res.keys())
                df_results = pd.concat([df_results, df_res], axis=0, ignore_index=True, sort=False)
                df_results.to_csv(config['results_filename'], index=None, header=True)
    
    acc = df_results.test_accuracy.mean()
    print('accuracy:%.2f' % acc)
    
    return df_results

# %%
import random
import ray
import ray.tune as tune

def get_6_digits():
    str_digits =  ''
    for i in range(6):
        digit = random.randint(0,9)
        str_digits += str(digit)
    return(str_digits)
        
def ray_train_and_tests(config):
        
        # update config with two additional parameters related to phonemes
        config = extend_config(config) 
        config['ray_tune'] = True
        
        ray_instance = 'ray_test_'+ get_6_digits()        
        #config['trial_dir'] = os.getcwd()
        #+ '/' + config['root_label'] + '_' + ray_instance
        print(config)
        
        df_results = train_and_tests(config)
        acc = df_results.test_accuracy.mean()
        tune.report(accuracy=acc)
        
        
def finetune_hyperparameters():

    FINETUNING_CONFIG = {            
        'episodes': tune.grid_search([3]),
        'n_train': tune.grid_search([10000]),
        'n_layer': tune.grid_search([2, 4]),
        'n_head': tune.grid_search([4]), 
        'n_embd': tune.grid_search([336]),
        'batch_size': tune.grid_search([128, 256]),        
    }
    
    test_name = 'ray_test_' + get_6_digits()
    print('test_name:%s' % test_name)

    # https://docs.ray.io/en/latest/tune/api_docs/execution.html?highlight=tune%20run
    analysis = tune.run(
        ray_train_and_tests, 
        config=FINETUNING_CONFIG, 
        resources_per_trial={'gpu': 4},
        name=test_name,
        local_dir= os.getcwd() + '/' + 'ray_results',
        metric="accuracy", 
        mode="max"
        )

    print("Best config: ", analysis.get_best_config())

    # Get a dataframe for analyzing trial results.
    df_ray = analysis.dataframe()

    return df_ray

# %%
def main():
    config = extend_config(CONFIG)
    if config['do_finetune']:
        ray.init()
        df_results = finetune_hyperparameters()
    else:
        if config['do_train']:
            df_results = train_and_tests(config)
        else:
            df_results = tests(config)
    return df_results

# %%
df_results = main()
# Out:
# episode: 0
# en: processing "write" data from /home/arc/oteann/subdatasets/en_wikt_samples.csv
# en: processing "read" data from /home/arc/oteann/subdatasets/en_wikt_samples.csv
# fr: processing "write" data from /home/arc/oteann/subdatasets/fr_wikt_samples.csv
# fr: processing "read" data from /home/arc/oteann/subdatasets/fr_wikt_samples.csv
# config['train_filename']: /home/arc/oteann/oteann_10099_train.csv
# data has 1124664 characters, 330 unique.
# ANN parameters: 5680080
#   0%|          | 0/4393 [00:00<?, ?it/s]/home/arc/oteann/oteann/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:61: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# epoch 1 iter 4392: train loss 0.75871. lr 3.000341e-04: 100%|██████████| 4393/4393 [04:59<00:00, 14.69it/s]
# epoch 2 iter 4392: train loss 0.64216. lr 6.000000e-05: 100%|██████████| 4393/4393 [04:59<00:00, 14.69it/s]
# training_duration 0:10:00.440809
# input: en,write,pɛbəl => prediction:peble KO! (target:pebble)
# input: en,write,zoʊɑdəmi => prediction:zooadomy KO! (target:zootomy)
# input: en,write,səʊd => prediction:sode KO! (target:sewed)
# input: en,write,mjʊəɹəl => prediction:mural ok (target:mural)
# input: en,write,kənsɪdəɹət => prediction:concederate KO! (target:considerate)
# input: en,write,kəθɛksɪs => prediction:cathexis ok (target:cathexis)
# input: en,write,dɪklaɪnd => prediction:declined ok (target:declined)
# input: en,write,əʊvəθɹəʊəl => prediction:overthroweal KO! (target:overthrowal)
# input: en,write,æfɹɪkeɪt => prediction:affricate ok (target:affricate)
# input: en,write,ɑbkɑɹ => prediction:abkar ok (target:abkar)
# input: en,write,fɛtʃ => prediction:fetch ok (target:fetch)
# input: en,write,əfɔɹmɛnʃənd => prediction:afformentioned KO! (target:aforementioned)
# input: en,write,pɹɒbəbli => prediction:probably ok (target:probably)
# input: en,write,ʌnblɪŋkɪŋli => prediction:unblinkingly ok (target:unblinkingly)
# input: en,write,hɑːvɪst => prediction:harvist KO! (target:harvest)
# input: en,write,æntaɪsɛns => prediction:anticence KO! (target:antisense)
# input: en,write,ɹɪmɛmbəd => prediction:remembaded KO! (target:remembered)
# input: en,write,maɪkɹəʊweɪv => prediction:microwave ok (target:microwave)
# input: en,write,ɑkjəlɚli => prediction:ocularly ok (target:ocularly)
# input: en,write,æmbɪliːvəs => prediction:ambilivous KO! (target:ambilevous)
# input: en,write,bɹiːz => prediction:bries KO! (target:breeze)
# input: en,write,wæks => prediction:wacks KO! (target:wax)
# input: en,write,baɪænjuːʌliː => prediction:bianullee KO! (target:biannually)
# input: en,write,ɪmpɔɹtuːn => prediction:importune ok (target:importune)
# input: en,write,kætʃəɹ => prediction:cacher KO! (target:catcher)
# input: en,write,flaɪz => prediction:flies ok (target:flies)
# input: en,write,kəɹeɪdɪeɪt => prediction:coradiate KO! (target:corradiate)
# input: en,write,ɡæmbɪt => prediction:gambit ok (target:gambit)
# input: en,write,stɒlən => prediction:stolen KO! (target:stollen)
# input: en,write,ɡɹɪməs => prediction:grimus KO! (target:grimace)
# input: en,write,pɒpə => prediction:popper KO! (target:poppa)
# input: en,write,nɛsəsɛɹəli => prediction:necessorially KO! (target:necessarily)
# input: en,write,dɹæm => prediction:dram KO! (target:drachm)
# input: en,write,kwɪnteɪʃən => prediction:quintation ok (target:quintation)
# input: en,write,maʊt => prediction:mout KO! (target:mought)
# input: en,write,buːzəɹ => prediction:booser KO! (target:boozer)
# input: en,write,ɡɒɡəl => prediction:goggle ok (target:goggle)
# input: en,write,sɪmiːs => prediction:simiece KO! (target:semese)
# input: en,write,sʌmweɪ => prediction:someway ok (target:someway)
# input: en,write,mʌɡi => prediction:muggy ok (target:muggy)
# input: en,write,doʊsənt => prediction:docent ok (target:docent)
# input: en,write,eɪoʊ => prediction:ayoo KO! (target:ayo)
# input: en,write,ʃɹɪl => prediction:shrill ok (target:shrill)
# input: en,write,kəlɪɡɹəfəɹ => prediction:colligrapher KO! (target:calligrapher)
# input: en,write,vɔːpl => prediction:vorple KO! (target:vorpal)
# input: en,write,æbsəlutɪstɪkli => prediction:absolutically KO! (target:absolutistically)
# input: en,write,plɛʒəz => prediction:pleas KO! (target:pleasures)
# input: en,write,skwɛltʃt => prediction:squelched ok (target:squelched)
# input: en,write,ɪntɹɪkət => prediction:intrict KO! (target:intricate)
# input: en,write,doʊ => prediction:dho KO! (target:doe)
# input: en,write,tɛɹəmɑːɹɪ => prediction:terramari KO! (target:terramare)
# input: en,write,iːv => prediction:eave KO! (target:eve)
# input: en,write,dəʊsiːtɪzəm => prediction:dosetism KO! (target:docetism)
# input: en,write,ælkəmɪst => prediction:alchamist KO! (target:alchemist)
# input: en,write,məɹeɪn => prediction:morene KO! (target:moraine)
# input: en,write,wiːdi => prediction:wheedy KO! (target:weedy)
# input: en,write,ɑːdjuːɪti => prediction:adeuity KO! (target:arduity)
# input: en,write,mɛdɪiːvəldəm => prediction:mediaevaldm KO! (target:mediævaldom)
# input: en,write,kwiːf => prediction:queef ok (target:queef)
# input: en,write,sɛpt => prediction:sept ok (target:sept)
# input: en,write,wɔtɛkʌlɛ => prediction:watecollait KO! (target:watercolour)
# input: en,write,fɔɹsfəl => prediction:forceful ok (target:forceful)
# input: en,write,tæli => prediction:tallee KO! (target:tally)
# input: en,write,fɹæti => prediction:fratty ok (target:fratty)
# input: en,write,bɹɪkɪŋ => prediction:bricking ok (target:bricking)
# input: en,write,æmbəlz => prediction:ambles ok (target:ambles)
# input: en,write,ɡleɪbɹɛsənt => prediction:glabrescent ok (target:glabrescent)
# input: en,write,əɡæst => prediction:agast KO! (target:aghast)
# input: en,write,snuːd => prediction:snood ok (target:snood)
# input: en,write,ʌnɹævəl => prediction:unravel ok (target:unravel)
# input: en,write,kɒɹɒɡɹəfə => prediction:corugrapher KO! (target:chorographer)
# input: en,write,bɛndʒəmɪn => prediction:benjamine KO! (target:benjamin)
# input: en,write,fuːtlɪŋ => prediction:footling ok (target:footling)
# input: en,write,sɪmbəlaɪz => prediction:cymbalize KO! (target:symbolize)
# input: en,write,waɪf => prediction:wife ok (target:wife)
# input: en,write,sælv => prediction:salve ok (target:salve)
# input: en,write,suːbɪtəʊ => prediction:subito ok (target:subito)
# input: en,write,taɪəd => prediction:tiired KO! (target:tired)
# input: en,write,kənvɛntɪkəl => prediction:conventical KO! (target:conventicle)
# input: en,write,fiːbɹaɪl => prediction:febrile ok (target:febrile)
# input: en,write,kəntɹækʃən => prediction:contraction ok (target:contraction)
# input: en,write,ɛkstɛndɪŋ => prediction:extending ok (target:extending)
# input: en,write,pəsɑːtə => prediction:passarta KO! (target:passata)
# input: en,write,kɑmplɛks => prediction:complex ok (target:complex)
# input: en,write,peɪntbɹʌʃ => prediction:paintbrush ok (target:paintbrush)
# input: en,write,dɪspɛptɪk => prediction:despetic KO! (target:dyspeptic)
# input: en,write,ædəlɪŋ => prediction:adaling KO! (target:adeling)
# input: en,write,æbəsi => prediction:abbassi KO! (target:abbacy)
# input: en,write,beɪtɪŋz => prediction:batings KO! (target:baitings)
# input: en,write,lɛɡɪd => prediction:leggid KO! (target:legged)
# input: en,write,mɪnjʊɛnd => prediction:minuend ok (target:minuend)
# input: en,write,ɡeɪp => prediction:gape ok (target:gape)
# input: en,write,juːən => prediction:uan KO! (target:yewen)
# input: en,write,pɑːz => prediction:pars KO! (target:parse)
# input: en,write,kɹuːdli => prediction:crudely ok (target:crudely)
# input: en,write,faɪnɪst => prediction:phynist KO! (target:finest)
# input: en,write,alkəhɛst => prediction:alkahest KO! (target:alcahest)
# input: en,write,leɪtəs => prediction:latus ok (target:latus)
# input: en,write,liːps => prediction:leeps KO! (target:leaps)
# input: en,write,tɹɒklɪəɹ => prediction:trocler KO! (target:trochlear)
# en write: n=100, n_ok=42, n_ko=58 => %n_ok=42%
# input: en,read,ti => prediction:ti KO! (target:tiː)
# input: en,read,shtum => prediction:ʃtʌm KO! (target:ʃtʊm)
# input: en,read,rooftree => prediction:ɹʊftɹi KO! (target:ɹuːftɹiː)
# input: en,read,dues => prediction:duːz KO! (target:djuːz)
# input: en,read,oblige => prediction:ɒblaɪdʒ KO! (target:əblaɪdʒ)
# input: en,read,panipuri => prediction:pænɪpjʊəɹi KO! (target:pɑnipʊɹi)
# input: en,read,provost => prediction:pɹɒvəst KO! (target:pɹoʊvoʊst)
# input: en,read,mung => prediction:mʌŋ ok (target:mʌŋ)
# input: en,read,invigilator => prediction:ɪnvɪdʒɪleɪtə KO! (target:ɪnvɪdʒɪleɪtəɹ)
# input: en,read,decurrence => prediction:diːkjəɹəns KO! (target:dɪkʌɹəns)
# input: en,read,mangled => prediction:mæŋɡəld ok (target:mæŋɡəld)
# input: en,read,strode => prediction:stɹəʊd KO! (target:stɹoʊd)
# input: en,read,caffeine => prediction:kəfiːniːn KO! (target:kæfiːn)
# input: en,read,ology => prediction:əʊlədʒi KO! (target:ɒlədʒɪ)
# input: en,read,footwell => prediction:fʊtwɛl ok (target:fʊtwɛl)
# input: en,read,dippings => prediction:dɪpɪŋz ok (target:dɪpɪŋz)
# input: en,read,hidden => prediction:hɪdən ok (target:hɪdən)
# input: en,read,hallucinogenic => prediction:həluːsɪnədʒɛnɪk KO! (target:həlusənədʒenɪk)
# input: en,read,swallie => prediction:swɑli KO! (target:swalɪ)
# input: en,read,lysozyme => prediction:lɪsəm KO! (target:laɪsəzaɪm)
# input: en,read,sides => prediction:saɪdz ok (target:saɪdz)
# input: en,read,axed => prediction:æksɪd KO! (target:ækst)
# input: en,read,glitzy => prediction:ɡlɪtsi ok (target:ɡlɪtsi)
# input: en,read,pound => prediction:paʊnd ok (target:paʊnd)
# input: en,read,lexemes => prediction:lɛksɪmz KO! (target:lɛksiːmz)
# input: en,read,rings => prediction:ɹɪŋz ok (target:ɹɪŋz)
# input: en,read,delivery => prediction:dɪlɪvəɹi ok (target:dɪlɪvəɹi)
# input: en,read,naggy => prediction:næɡi KO! (target:næɡiː)
# input: en,read,blandishment => prediction:blændɪʃmənt KO! (target:blændɪʃmnt)
# input: en,read,esteemed => prediction:ɪstiːmd ok (target:ɪstiːmd)
# input: en,read,abranchious => prediction:eɪbɹæŋkiəs ok (target:eɪbɹæŋkiəs)
# input: en,read,weatherbound => prediction:wɛθɚbaʊnd KO! (target:wɛðəbaʊnd)
# input: en,read,stannous => prediction:stænəs ok (target:stænəs)
# input: en,read,weever => prediction:wiːvə KO! (target:wivɚ)
# input: en,read,epiphyllospermous => prediction:ɛpɪfɪlɒspəɹməs KO! (target:ɛpɪfɪləspɛːɹməs)
# input: en,read,foresee => prediction:fəɹsiː KO! (target:fɔːsiː)
# input: en,read,comma => prediction:kɒmə KO! (target:kɑmə)
# input: en,read,antennae => prediction:æntɛneɪ KO! (target:æntɛni)
# input: en,read,yasht => prediction:jɒʃ KO! (target:jæʃt)
# input: en,read,algebraic => prediction:ældʒɪbɹeɪɪk ok (target:ældʒɪbɹeɪɪk)
# input: en,read,gunnel => prediction:ɡʌnəl KO! (target:ɡʌnl)
# input: en,read,wizen => prediction:wɪzən ok (target:wɪzən)
# input: en,read,recess => prediction:ɹiːsɪz KO! (target:ɹiːsɛs)
# input: en,read,ode => prediction:əʊd ok (target:əʊd)
# input: en,read,ruined => prediction:ɹuːɪnd KO! (target:ɹuːnd)
# input: en,read,tune => prediction:tjuːn KO! (target:tjun)
# input: en,read,skens => prediction:skɛnz ok (target:skɛnz)
# input: en,read,faceplant => prediction:feɪsplænt ok (target:feɪsplænt)
# input: en,read,acromegalic => prediction:ækɹəmɛɡəlɪk KO! (target:akɹəʊmɪɡalɪk)
# input: en,read,granulocyte => prediction:ɡɹanjuːləsaɪt KO! (target:ɡɹænjəloʊsaɪt)
# input: en,read,injured => prediction:ɪndʒjʊɹd KO! (target:ɪndʒəd)
# input: en,read,agonous => prediction:æɡənəs ok (target:æɡənəs)
# input: en,read,pastes => prediction:peɪsts ok (target:peɪsts)
# input: en,read,greens => prediction:ɡɹiːnz ok (target:ɡɹiːnz)
# input: en,read,unflighty => prediction:ʌnflaɪti KO! (target:ənflaɪti)
# input: en,read,gazabo => prediction:ɡəzɑbaʊ KO! (target:ɡəzeɪbəʊ)
# input: en,read,darned => prediction:dɑːnd ok (target:dɑːnd)
# input: en,read,repdigit => prediction:ɹɛpdɪdʒɪt ok (target:ɹɛpdɪdʒɪt)
# input: en,read,pointed => prediction:pɔɪntɪd ok (target:pɔɪntɪd)
# input: en,read,studded => prediction:stʌdɪd ok (target:stʌdɪd)
# input: en,read,unified => prediction:juːnəfaɪd KO! (target:juːnɪfaɪd)
# input: en,read,lockstitch => prediction:lɒkstɪθ KO! (target:lɑkstɪtʃ)
# input: en,read,swivet => prediction:swaɪvɪt KO! (target:swɪvɪt)
# input: en,read,smokehouse => prediction:sməʊkhaʊs KO! (target:smoʊkhaʊs)
# input: en,read,switch => prediction:swɪtʃ ok (target:swɪtʃ)
# input: en,read,wallflower => prediction:wælfələʊəɹ KO! (target:wɔlflɑʊɚ)
# input: en,read,hyperrelativism => prediction:haɪpɚɹɛlətɪvɪzm ok (target:haɪpɚɹɛlətɪvɪzm)
# input: en,read,login => prediction:lɒdʒɪn KO! (target:lɒɡɪn)
# input: en,read,metropoleis => prediction:mɛtɹəpoʊliz KO! (target:mɛtɹɒpəleɪz)
# input: en,read,shoop => prediction:ʃuːp ok (target:ʃuːp)
# input: en,read,reactionary => prediction:ɹɛkʃənɛɹi KO! (target:ɹiækʃənəɹi)
# input: en,read,œcumenic => prediction:juːkjuːmɛnɪk KO! (target:iːkjuːmɛnɪk)
# input: en,read,badger => prediction:bædʒəɹ KO! (target:bædʒə)
# input: en,read,slip => prediction:slɪp ok (target:slɪp)
# input: en,read,bragfest => prediction:bɹæɡfɛst ok (target:bɹæɡfɛst)
# input: en,read,pish => prediction:pɪʃ ok (target:pɪʃ)
# input: en,read,abductively => prediction:æbdʌktɪvli ok (target:æbdʌktɪvli)
# input: en,read,amoeba => prediction:əmiːbə ok (target:əmiːbə)
# input: en,read,metacercaria => prediction:mɪtæsəɹiə KO! (target:mɛtəsɛːɹkɛəɹɪə)
# input: en,read,excentric => prediction:ɛksɛntɹɪs KO! (target:ɛkssɛntɹɪk)
# input: en,read,lawyer => prediction:lɔːjə KO! (target:lɔjɚ)
# input: en,read,risen => prediction:ɹaɪzən KO! (target:ɹɪzən)
# input: en,read,reconcile => prediction:ɹɪkənsʌɪl KO! (target:ɹɛkənsaɪl)
# input: en,read,aborigine => prediction:əbɔɹədʒɪn KO! (target:æbəɹɪdʒɪni)
# input: en,read,acceptor => prediction:əksɛptə KO! (target:əksɛptəɹ)
# input: en,read,heteronym => prediction:hɛtəɹoʊnɪm ok (target:hɛtəɹoʊnɪm)
# input: en,read,someways => prediction:sɒmweɪs KO! (target:sʌmweɪz)
# input: en,read,sachem => prediction:sæʃəm KO! (target:seɪtʃəm)
# input: en,read,gennaker => prediction:dʒɛnəkɚ KO! (target:dʒɛnəkəɹ)
# input: en,read,canalise => prediction:kənalaɪz KO! (target:kənælaɪz)
# input: en,read,interrupt => prediction:ɪntəɹʌpt ok (target:ɪntəɹʌpt)
# input: en,read,daybook => prediction:deɪbʊk ok (target:deɪbʊk)
# input: en,read,retort => prediction:ɹiːtɔɹt KO! (target:ɹɪtɔːt)
# input: en,read,wayward => prediction:weɪwɔːd KO! (target:weɪwɚd)
# input: en,read,suddenly => prediction:sʌdiːnli KO! (target:sʌdnli)
# input: en,read,fixedness => prediction:fɪksɪdnɪs KO! (target:fɪksɪdnəs)
# input: en,read,achieves => prediction:əʃiːvz KO! (target:ətʃiːvz)
# input: en,read,component => prediction:kəmpəʊnənt KO! (target:kʌmpoʊnənt)
# input: en,read,shunned => prediction:ʃʌnd ok (target:ʃʌnd)
# input: en,read,sincerity => prediction:sɪnsəɹɪti KO! (target:sɪnsɛɹəti)
# en  read: n=100, n_ok=37, n_ko=63 => %n_ok=37%
# input: fr,write,ɑ̃tʁəlasɛ => prediction:entrelassait KO! (target:entrelaçait)
# input: fr,write,ɛ̃dəmɑ̃de => prediction:indemendée KO! (target:indemandé)
# input: fr,write,nakʁe => prediction:nacrés KO! (target:nacrées)
# input: fr,write,destabilizɑ̃t => prediction:déstabilisante KO! (target:déstabilisantes)
# input: fr,write,bʁiʃbʁɔʃa => prediction:brichebrochas KO! (target:brichebrochât)
# input: fr,write,myskatɛlin => prediction:muscateline KO! (target:muscatelline)
# input: fr,write,tanatɔmɛtʁ => prediction:tanatomètres KO! (target:thanatomètre)
# input: fr,write,ʁatəle => prediction:rattelés KO! (target:râtelé)
# input: fr,write,baʁɡɛna => prediction:bargainas KO! (target:bargainât)
# input: fr,write,ʁəsakʁifisiʁɛ => prediction:resacrificierais KO! (target:resacrificierait)
# input: fr,write,detalɛ̃ɡəʁa => prediction:détalingueras KO! (target:détalinguera)
# input: fr,write,denɔ̃bʁa => prediction:dénombra KO! (target:dénombras)
# input: fr,write,syʁvɔltəʁa => prediction:survolteras KO! (target:survoltera)
# input: fr,write,ɔziʁjanizɛ => prediction:osirianisaient ok (target:osirianisaient)
# input: fr,write,bʁɥisɑ̃ => prediction:bruissant KO! (target:bruissants)
# input: fr,write,evidɑ̃tjalizəʁjɔ̃ => prediction:évidentialiserions ok (target:évidentialiserions)
# input: fr,write,ɑ̃kwafe => prediction:encouaffée KO! (target:encoiffer)
# input: fr,write,ʁəpʁɔstɛʁne => prediction:reprosternez KO! (target:reprosternai)
# input: fr,write,kopʁɔdɥizjɔ̃ => prediction:coproduisions ok (target:coproduisions)
# input: fr,write,tɛʁʒivɛʁsəʁɛ => prediction:tergiverserait KO! (target:tergiverseraient)
# input: fr,write,tɔk => prediction:tauques KO! (target:toquent)
# input: fr,write,bɔlɛ̃ʃasjɔ̃ => prediction:bolynchassions KO! (target:bolinchassions)
# input: fr,write,sɔsjɔlɔʒisizəʁɛ => prediction:sociologiseraient KO! (target:sociologiciserait)
# input: fr,write,dʁwatiz => prediction:droitisent KO! (target:droitises)
# input: fr,write,ʁeɔksitanizɛ => prediction:réoxytanisais KO! (target:réoccitanisais)
# input: fr,write,idee => prediction:ideɔlɔʒizje,idéologisiez KO! (target:idéé)
# input: fr,write,ɑ̃tʁəpase => prediction:entrepacer KO! (target:entrepassé)
# input: fr,write,nekʁɔmɑ̃tizɛʁ => prediction:nécromantisèrent ok (target:nécromantisèrent)
# input: fr,write,ʁəkʁɔnɔmetʁije => prediction:recronométriez KO! (target:rechronométriez)
# input: fr,write,ʁeatʁapɔ̃ => prediction:réattrapons ok (target:réattrapons)
# input: fr,write,ʁɑ̃dɔmize => prediction:rendomisés KO! (target:randomisé)
# input: fr,write,ɑ̃tʁəpwaɲaʁd => prediction:entrepoignardes KO! (target:entrepoignardent)
# input: fr,write,ʁəspiʁalizje => prediction:respiralisiez ok (target:respiralisiez)
# input: fr,write,diskuʁizəʁe => prediction:discouriserez ok (target:discouriserez)
# input: fr,write,fotokatalizasjɔ̃ => prediction:photocatalysassions ok (target:photocatalysassions)
# input: fr,write,ɛskanəʁa => prediction:escanera KO! (target:escaneras)
# input: fr,write,ybɛʁizas => prediction:uberisasse KO! (target:uberisasses)
# input: fr,write,ɑ̃bɔdinyʁ => prediction:embodinures ok (target:embodinures)
# input: fr,write,liɡatyʁəʁjɔ̃ => prediction:liggaturerions KO! (target:ligaturerions)
# input: fr,write,pʁeɡutje => prediction:prégoûtiez ok (target:prégoûtiez)
# input: fr,write,ɑ̃ʒoʒa => prediction:angeaugea KO! (target:enjaugeas)
# input: fr,write,dezastʁɔlɔʒizasje => prediction:désastrologisassiez ok (target:désastrologisassiez)
# input: fr,write,tipɔtəʁa => prediction:tipotera KO! (target:tirlipotera)
# input: fr,write,ʃɛʁʃasjɔ̃ => prediction:cherchassions ok (target:cherchassions)
# input: fr,write,aʁaneøz => prediction:arranéeuses KO! (target:aranéeuse)
# input: fr,write,kɔlabɔʁ => prediction:collabore KO! (target:collabores)
# input: fr,write,eɡɔbləʁe => prediction:égobelerai KO! (target:égoblerai)
# input: fr,write,ekalabʁas => prediction:écalabrassent KO! (target:écalabrasse)
# input: fr,write,ɡʁiɲ => prediction:grignent ok (target:grignent)
# input: fr,write,desinizat => prediction:désynisâtes KO! (target:désinisâtes)
# input: fr,write,ʁeɛ̃fɑ̃tilizas => prediction:réinfentilisasse KO! (target:réinfantilisasse)
# input: fr,write,bʁɔʃaʒ => prediction:brochages KO! (target:brochage)
# input: fr,write,desizjɔnɛl => prediction:désisionnels KO! (target:décisionnelle)
# input: fr,write,ʃɑ̃bʁe => prediction:chambrai KO! (target:chambrez)
# input: fr,write,paʁʃase => prediction:parchassées KO! (target:parchassez)
# input: fr,write,kɑ̃tij => prediction:cantille KO! (target:cantilles)
# input: fr,write,tuʁnɑjas => prediction:tournaillasses ok (target:tournaillasses)
# input: fr,write,ʁəʒyʃəʁɔ̃ => prediction:rejucheront KO! (target:rejucherons)
# input: fr,write,deɡɔbijəʁɛ => prediction:dégobillerais KO! (target:dégobillerait)
# input: fr,write,pakɛʁ => prediction:paquèrent KO! (target:pacquèrent)
# input: fr,write,bizuna => prediction:bizouna KO! (target:bizounât)
# input: fr,write,deteatʁalizəʁɛ => prediction:détéatraliserais KO! (target:déthéâtraliserait)
# input: fr,write,pɛizana => prediction:paysanas KO! (target:paysanna)
# input: fr,write,psikɔlɔɡ => prediction:psychologue KO! (target:psychologuent)
# input: fr,write,adyktɛ => prediction:aductais KO! (target:adductais)
# input: fr,write,anaɡʁamatizas => prediction:anagrammatisasses ok (target:anagrammatisasses)
# input: fr,write,dezɑ̃butɛjəʁje => prediction:désembouteilleriez ok (target:désembouteilleriez)
# input: fr,write,ʁəmakɛtəʁe => prediction:remaquèterai KO! (target:remaquetterai)
# input: fr,write,defʁaɡmɑ̃te => prediction:défragmentée KO! (target:défragmenté)
# input: fr,write,bulinas => prediction:boulinassent KO! (target:boulinasse)
# input: fr,write,ʁeɑ̃ʁolas => prediction:réenrolassent KO! (target:réenrôlasse)
# input: fr,write,satanəʁɛ => prediction:sataneraient KO! (target:satanerait)
# input: fr,write,tʁɑ̃skʁivjɔ̃ => prediction:transcrivions ok (target:transcrivions)
# input: fr,write,plykas => prediction:plucassent KO! (target:pluquassent)
# input: fr,write,aɡʁɛnwaʁ => prediction:agrainoir KO! (target:agrainoirs)
# input: fr,write,dekapitalizɛ => prediction:décapitalisaient ok (target:décapitalisaient)
# input: fr,write,ʁeaʃalɑ̃de => prediction:réachalandées KO! (target:réachalandée)
# input: fr,write,libeʁjanizəʁɔ̃ => prediction:libérianiseront ok (target:libérianiseront)
# input: fr,write,kʁɔʃəʁɛ => prediction:crocherait KO! (target:crocheraient)
# input: fr,write,tʁaktasje => prediction:tractassiez ok (target:tractassiez)
# input: fr,write,depʁekaʁiza => prediction:déprécarisa KO! (target:déprécarisât)
# input: fr,write,ʁəʒemiʁ => prediction:regémires KO! (target:regémir)
# input: fr,write,kolɔkaʁp => prediction:colocarpes KO! (target:caulocarpes)
# input: fr,write,falsifjɛ => prediction:falsifiaient ok (target:falsifiaient)
# input: fr,write,dɛltaize => prediction:deltaïsai KO! (target:deltaïsées)
# input: fr,write,afʁeʁismɑ̃ => prediction:affrérissements ok (target:affrérissements)
# input: fr,write,ʁəbʁavɛʁ => prediction:rebravèrent ok (target:rebravèrent)
# input: fr,write,senjɔʁizəʁɔ̃ => prediction:cénioriserons KO! (target:sénioriseront)
# input: fr,write,dyʁabl => prediction:durables KO! (target:durable)
# input: fr,write,aktɥalize => prediction:actualisées KO! (target:actualisé)
# input: fr,write,memɔʁizabl => prediction:mémorisables ok (target:mémorisables)
# input: fr,write,kameljɛ̃ => prediction:caméliens KO! (target:camélien)
# input: fr,write,sinematɛk => prediction:sinématecs KO! (target:cinémathèque)
# input: fr,write,alakje => prediction:alacquiez KO! (target:alaquiez)
# input: fr,write,devɛʁbalizas => prediction:déverbalisassent KO! (target:déverbalisasse)
# input: fr,write,stasjɔnaʁiz => prediction:stationnarises ok (target:stationnarises)
# input: fr,write,kavijmɑ̃ => prediction:cavillement KO! (target:cavillements)
# input: fr,write,kaʁtune => prediction:cartoonnés KO! (target:cartoonées)
# input: fr,write,ʁeɛspjɔnje => prediction:réespionniez ok (target:réespionniez)
# input: fr,write,otosyblime => prediction:autosublimez KO! (target:autosublimés)
# fr write: n=100, n_ok=26, n_ko=74 => %n_ok=26%
# input: fr,read,plaida => prediction:pledɛ KO! (target:pleda)
# input: fr,read,sacaillèrent => prediction:sakajɛʁ ok (target:sakajɛʁ)
# input: fr,read,carrelaient => prediction:kaʁəlɛ ok (target:kaʁəlɛ)
# input: fr,read,dégoûtants => prediction:deɡutɑ̃ ok (target:deɡutɑ̃)
# input: fr,read,convicts => prediction:kɔ̃vik KO! (target:kɔ̃vikt)
# input: fr,read,giguassent => prediction:ʒiɡas ok (target:ʒiɡas)
# input: fr,read,réarroses => prediction:ʁeaʁɔz KO! (target:ʁeaʁoz)
# input: fr,read,poupounes => prediction:pupun ok (target:pupun)
# input: fr,read,calmar => prediction:kalmaʁ ok (target:kalmaʁ)
# input: fr,read,racquises => prediction:ʁakiz ok (target:ʁakiz)
# input: fr,read,désenchaînons => prediction:dezɑ̃ʃɛnɔ̃ ok (target:dezɑ̃ʃɛnɔ̃)
# input: fr,read,étampoises => prediction:etɑ̃pwaz ok (target:etɑ̃pwaz)
# input: fr,read,préamplifiées => prediction:pʁeɑ̃plifje ok (target:pʁeɑ̃plifje)
# input: fr,read,désétablissez => prediction:dezetablise ok (target:dezetablise)
# input: fr,read,décharpissent => prediction:deʃaʁpis ok (target:deʃaʁpis)
# input: fr,read,palancrassiez => prediction:palɑ̃kʁasje ok (target:palɑ̃kʁasje)
# input: fr,read,restrippâtes => prediction:ʁəstʁipat ok (target:ʁəstʁipat)
# input: fr,read,cachemirisai => prediction:kaʃmiʁize ok (target:kaʃmiʁize)
# input: fr,read,essentiel => prediction:ɛsɑ̃tjɛl KO! (target:esɑ̃sjɛl)
# input: fr,read,résinifiiez => prediction:ʁezinifije ok (target:ʁezinifije)
# input: fr,read,chapardeurs => prediction:ʃapaʁdœʁ ok (target:ʃapaʁdœʁ)
# input: fr,read,toulousianisas => prediction:tuluzjaniza KO! (target:tulusjaniza)
# input: fr,read,bonimente => prediction:bɔnimɑ̃t ok (target:bɔnimɑ̃t)
# input: fr,read,redéconcertaient => prediction:ʁədekɔ̃sɛʁtɛ ok (target:ʁədekɔ̃sɛʁtɛ)
# input: fr,read,fripassiez => prediction:fʁipasje ok (target:fʁipasje)
# input: fr,read,rechicotez => prediction:ʁəʃikɔte ok (target:ʁəʃikɔte)
# input: fr,read,retreindraient => prediction:ʁətʁɛ̃dʁɛ ok (target:ʁətʁɛ̃dʁɛ)
# input: fr,read,désexcommunia => prediction:dezɛkskɔmynja ok (target:dezɛkskɔmynja)
# input: fr,read,surjouas => prediction:syʁʒwa ok (target:syʁʒwa)
# input: fr,read,enliserait => prediction:ɑ̃lizəʁɛ ok (target:ɑ̃lizəʁɛ)
# input: fr,read,brédirai => prediction:bʁediʁe ok (target:bʁediʁe)
# input: fr,read,modernisé => prediction:mɔdɛʁnize ok (target:mɔdɛʁnize)
# input: fr,read,verdoyâmes => prediction:vɛʁdwam KO! (target:vɛʁdwajam)
# input: fr,read,téléportant => prediction:telepɔʁtɑ̃ ok (target:telepɔʁtɑ̃)
# input: fr,read,surlikassiez => prediction:syʁlikasje KO! (target:syʁlajkasje)
# input: fr,read,noirismes => prediction:nwaʁism ok (target:nwaʁism)
# input: fr,read,vignèteront => prediction:viɲɛtəʁɔ̃ ok (target:viɲɛtəʁɔ̃)
# input: fr,read,anthroponymisée => prediction:ɑ̃tʁɔpɔnimize KO! (target:ɑ̃tʁoponimize)
# input: fr,read,épouillassent => prediction:epujas ok (target:epujas)
# input: fr,read,redélasserais => prediction:ʁədelasəʁɛ ok (target:ʁədelasəʁɛ)
# input: fr,read,enquinauderez => prediction:ɑ̃kinodəʁe ok (target:ɑ̃kinodəʁe)
# input: fr,read,robines => prediction:ʁɔbin ok (target:ʁɔbin)
# input: fr,read,guinderons => prediction:ɡɛ̃dəʁɔ̃ ok (target:ɡɛ̃dəʁɔ̃)
# input: fr,read,mésestimassent => prediction:mezɛstimas ok (target:mezɛstimas)
# input: fr,read,instagrammerez => prediction:ɛ̃staɡʁaməʁe ok (target:ɛ̃staɡʁaməʁe)
# input: fr,read,courbu => prediction:kuʁby ok (target:kuʁby)
# input: fr,read,baronnifie => prediction:baʁɔnifi ok (target:baʁɔnifi)
# input: fr,read,clochetèrent => prediction:klɔʃətɛʁ ok (target:klɔʃətɛʁ)
# input: fr,read,triquées => prediction:tʁike ok (target:tʁike)
# input: fr,read,chapitreriez => prediction:ʃapitʁəʁje ok (target:ʃapitʁəʁje)
# input: fr,read,surréaction => prediction:syʁʁeaksjɔ̃ ok (target:syʁʁeaksjɔ̃)
# input: fr,read,exacandélas => prediction:ɛɡzakɑ̃dela ok (target:ɛɡzakɑ̃dela)
# input: fr,read,repersécutais => prediction:ʁəpɛʁsekytɛ ok (target:ʁəpɛʁsekytɛ)
# input: fr,read,recompromettaient => prediction:ʁəkɔ̃pʁɔmɛtɛ ok (target:ʁəkɔ̃pʁɔmɛtɛ)
# input: fr,read,saussuritisait => prediction:sosyʁitizɛ ok (target:sosyʁitizɛ)
# input: fr,read,redéchausseras => prediction:ʁədeʃosəʁa ok (target:ʁədeʃosəʁa)
# input: fr,read,notionnelle => prediction:nɔsjɔnɛl ok (target:nɔsjɔnɛl)
# input: fr,read,redépasserai => prediction:ʁədepasəʁe ok (target:ʁədepasəʁe)
# input: fr,read,berlinisent => prediction:bɛʁliniz ok (target:bɛʁliniz)
# input: fr,read,barronnasse => prediction:baʁɔnas ok (target:baʁɔnas)
# input: fr,read,reprofessera => prediction:ʁəpʁɔfɛsəʁa ok (target:ʁəpʁɔfɛsəʁa)
# input: fr,read,velvétique => prediction:vɛlvetik ok (target:vɛlvetik)
# input: fr,read,écohabitèrent => prediction:ekoabitɛʁ ok (target:ekoabitɛʁ)
# input: fr,read,défluore => prediction:deflyɔʁ ok (target:deflyɔʁ)
# input: fr,read,pupitrâmes => prediction:pypitʁam ok (target:pypitʁam)
# input: fr,read,optionnelles => prediction:ɔpsjɔnɛl ok (target:ɔpsjɔnɛl)
# input: fr,read,bureaucratismes => prediction:byʁɔkʁatism KO! (target:byʁokʁatism)
# input: fr,read,repagnotassiez => prediction:ʁəpaɲɔtasje ok (target:ʁəpaɲɔtasje)
# input: fr,read,renaturalisas => prediction:ʁənatyʁaliza ok (target:ʁənatyʁaliza)
# input: fr,read,repiocherons => prediction:ʁəpjɔʃəʁɔ̃ KO! (target:ʁəpjoʃəʁɔ̃)
# input: fr,read,indigénisais => prediction:ɛ̃diʒenizɛ ok (target:ɛ̃diʒenizɛ)
# input: fr,read,rebanquetas => prediction:ʁəbɑ̃kəta ok (target:ʁəbɑ̃kəta)
# input: fr,read,désisolai => prediction:dezizɔle ok (target:dezizɔle)
# input: fr,read,récitations => prediction:ʁesitasjɔ̃ ok (target:ʁesitasjɔ̃)
# input: fr,read,cannelons => prediction:kantəlɔ̃ KO! (target:kanlɔ̃)
# input: fr,read,désanecdotisant => prediction:dezanɛkdɔtizɑ̃ ok (target:dezanɛkdɔtizɑ̃)
# input: fr,read,redérouteraient => prediction:ʁədeʁutəʁɛ ok (target:ʁədeʁutəʁɛ)
# input: fr,read,orthoxyquinoléine => prediction:ɔʁtɔksikinɔle KO! (target:ɔʁtoksikinolein)
# input: fr,read,restriquent => prediction:ʁəstʁik KO! (target:ʁɛstʁik)
# input: fr,read,spiréine => prediction:spiʁein ok (target:spiʁein)
# input: fr,read,démédicaliserait => prediction:demedikalizəʁɛ ok (target:demedikalizəʁɛ)
# input: fr,read,ovalerai => prediction:ovaləʁe KO! (target:ɔvaləʁe)
# input: fr,read,rembobinions => prediction:ʁɑ̃bɔbinjɔ̃ ok (target:ʁɑ̃bɔbinjɔ̃)
# input: fr,read,évocables => prediction:evɔkabl ok (target:evɔkabl)
# input: fr,read,compactifiiez => prediction:kɔ̃paktifje KO! (target:kɔ̃paktifije)
# input: fr,read,revoguent => prediction:ʁəvɔɡ ok (target:ʁəvɔɡ)
# input: fr,read,repleurnichant => prediction:ʁəplœʁniʃɑ̃ ok (target:ʁəplœʁniʃɑ̃)
# input: fr,read,rétraction => prediction:ʁetʁaksjɔ̃ ok (target:ʁetʁaksjɔ̃)
# input: fr,read,questionnaires => prediction:kestjɔnɛʁ KO! (target:kɛstjɔnɛʁ)
# input: fr,read,varioliser => prediction:vaʁjɔlize ok (target:vaʁjɔlize)
# input: fr,read,néoparler => prediction:neɔpaʁle ok (target:neɔpaʁle)
# input: fr,read,tictacquiez => prediction:tiktakje ok (target:tiktakje)
# input: fr,read,lizarique => prediction:lizaʁik ok (target:lizaʁik)
# input: fr,read,rembrouillâmes => prediction:ʁɑ̃bʁujam ok (target:ʁɑ̃bʁujam)
# input: fr,read,lourions => prediction:luʁjɔ̃ ok (target:luʁjɔ̃)
# input: fr,read,débrassait => prediction:debʁasɛ ok (target:debʁasɛ)
# input: fr,read,rentrainâmes => prediction:ʁɑ̃tʁɛnam ok (target:ʁɑ̃tʁɛnam)
# input: fr,read,algorithmisions => prediction:alɡɔʁitɔ̃ KO! (target:alɡɔʁitmizjɔ̃)
# input: fr,read,recarnais => prediction:ʁəkaʁnɛ ok (target:ʁəkaʁnɛ)
# input: fr,read,rechatassions => prediction:ʁəʃatasjɔ̃ KO! (target:ʁətʃatasjɔ̃)
# fr  read: n=100, n_ok=82, n_ko=18 => %n_ok=82%
# accuracy:0.47
